# %% [markdown]
# **CIENCIA DE DATOS**
#
# Mini Curso, Universidad Nacional
#
# Juan Esteban Puyo Cubillos

# %%
#Maquinas vector sporte

#Nosotros podemos separar con lineas los espacios en los que estamos trabajando

# %% [markdown]
# ![recta.png](data:image/png;base64,...)

# %%
#Un plano tiene la puede dividir el espacio en tres partes distintas

#el plano es de dimension 2 y divide un espacio de tres dimensiones

#un linea un espacio de 2 

#ahora se trabaja con un plano, al que se llama separador


#la dimensiones de los datos se determinan por el numero de caracteristicas

#para aprendizaje supervisado siempre existira una etiqueta y = [1 (positivos),-1 (negativos)]
#para crear parejas x,y

# %%
#para dimensiones mayor a 3 se hace una generalizacion

#dicha generalizacion se denomina hiperplano representado por una ecuacion

#w = vector de pesos
#b = umbral

# %% [markdown]
# ![Captura.PNG](data:image/png;base64,...)

# %%
#los datos para ser separables deben cumplir con una condicion

# %% [markdown]
# ![Captura1.PNG](data:image/png;base64,...)

# %%
#objetivo, encontrar w b

# %% [markdown]
# existen problemas en clasificacion, por ejemplo, datos no seperables linealmente en 2d

# %% [markdown]
# ![imag.png](data:image/png;base64,...)

# %% [markdown]
# es necesario **SUBIR a un espacio mas grande**
#
# \large{
# (x,y) \mapsto (x,y, x^2 + y^2)
# }.

# %% [markdown]
# Una de las operaciones mas importantes en algebra lineal
#
#
#
# ESCALAR
#
#
# x y * uw = xu + yw

# %% [markdown]
# general <x,z> = x1*z1.... etc

# %% [markdown]
# **Recordar** la norma = tamano del vector

# %% [markdown]
# Recordar proyeccion de otro vector

# %% [markdown]
# ![projection.png](data:image/png;base64,...)

# %%
 #ya se puede crear la funcion predictiva

# %% [markdown]
# ![Captura3.PNG](data:image/png;base64,...)

# %% [markdown]
# >0 por el plano
#
# <0 debajo del plano

# %% [markdown]
# ![Captura4.PNG](data:image/png;base64,...)

# %%
#se puede crear un algoritmo generico a partir de la funcion predictiva

# %%
#transformacion de los datos a r3, solo necesita el producto escalar al cuadrado.


#kernel, llevar los datos para hacer calculos en un espacio sin trasladar los datos a r3.

# %% [markdown]
# ![Captura5.PNG](data:image/png;base64,...)

# %% [markdown]
# a es peso, y es derivado de las etiquetas de y

# %% [markdown]
# **Margen funcional**
#
#
# espacio entre las dos separaciones por el separador
#
# si los datos son seperables deberia existir el margen de tal manera que toque ambos datos y dentro del margen no exista nada.
#
# Entre mas grande es el margen mas segura es la clasificacion.
#
# **la linea y el margen dan el svm**

# %% [markdown]
# Matriz de gram, es ncesitada para determinar el a de la funcion predictiva, para algoritmos no lineales se necesita calcular con el kernel, a traves de FI.

# %% [markdown]
# ![Captura6.PNG](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
from sklearn import svm, datasets


# import some data to play with
iris = datasets.load_iris()
# Take the first two features. We could avoid this by using a two-dim dataset
X = iris.data[:, :2]
y = iris.target

# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
models = (
    svm.SVC(kernel="linear", C=C),
    svm.LinearSVC(C=C, max_iter=10000),
    svm.SVC(kernel="rbf", gamma=0.7, C=C),
    svm.SVC(kernel="poly", degree=3, gamma="auto", C=C),
)
models = (clf.fit(X, y) for clf in models)
# title for the plots
titles = (
    "SVC con un kernel lineal",
    "LinearSVC (kernel lineal",
    "SVC con Kernel gaussiano ",
    "SVC with kernel polinomial (grado 3)",
)

# Set-up 2x2 grid for plotting.
fig, sub = plt.subplots(2, 2)
plt.subplots_adjust(wspace=0.4, hspace=0.4)

X0, X1 = X[:, 0], X[:, 1]
for clf, title, ax in zip(models, titles, sub.flatten()):
    
    ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors="k")
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)
plt.show()
