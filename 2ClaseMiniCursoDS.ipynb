# %% [markdown]
# **CIENCIA DE DATOS**
#
# Mini Curso, Universidad Nacional
#
# Juan Esteban Puyo Cubillos

# %%
#Clase de reducción de dimensionalidad


#Recordar

#Dimension de un punto, 0
#Dimension de una linea, 1, solo te puedes mover en dos direcciones
#Cuadrado?, depende

#Espira, dimension 1
#Cuadrado lleno, dos direcciones
#Tierra?, 3 dimensiones

#Dimension, grado de libertad en el que tu te puedes mover

#Hay 4

#Edwin Abbott, planilandia

#Paradoja de la linea de costa!

#Con una regla infinitamente precisa nunca se acabaría de medir

#LOS FRACTALES, resultado del debate de la paradoja de la linea de costa

#El trueno es un fractal
#Se auto repite su estructura

#DEFINICIÓN INFORMAL DE FRACTALES
#Minimo numero de coordenadas para describir los puntos de un objeto


#Los objetos de la realidad pueden ser represantos en 3 dimensiones


import pandas as pd
import numpy as np


df = pd.read_csv("auto_clean.csv")
pd.set_option('display.max_columns',29)
df.head()

df['length']


#Matplotlib Widget, para rotar las graficas

#Introduccion matplotlib

import matplotlib.pyplot as plt
# Sorpresa
# Dibujar Lienzo
fig = plt.figure(figsize=(5, 5))
# Dibujar Ejes
ax = plt.axes()
# Graficar Nube de Puntos
# Truco para graficar bien en 1D
y_0 = np.zeros(len(df))
# Valores de longitud
ax.scatter(df['length'], y_0, alpha = 0.4, s=60)
# Nombres de los Ejes
ax.set_xlabel("Length")
# Título
ax.set_title("Relación entre altura y ancho ")
# Mostrar Imagen (Opcional en JupyterLab)
plt.show()

# %%
import matplotlib.pyplot as plt


# Dibujar Lienzo
fig = plt.figure(figsize=(5, 5))

# Dibujar Ejes
ax = plt.axes()

# Graficar Nube de Puntos
y_0 = np.zeros(len(df))
ax.scatter(df['length'],y_0, alpha = 0.4, s=60)

# Nombres de los Ejes
ax.set_xlabel("Longitud")

# Título
ax.set_title("Valores de longitud")

# Mostrar Imagen (Opcional en JupyterLab)
plt.show()

# %%
df[['length','width']].head()


import matplotlib.pyplot as plt

# Sorpresa
#%matplotlib widget

# Cerrar figuras abiertas
plt.close('all')

# Dibujar Lienzo
fig = plt.figure(figsize=(8, 5))

# Dibujar Ejes
ax = plt.axes()

# Graficar Nube de Puntos
ax.scatter(df['length'], df['width'], alpha=0.4, s=60)

# Nombres de los Ejes
ax.set_xlabel("Longitud")
ax.set_ylabel("Ancho")

# Título
ax.set_title("Relación entre longitud y ancho")

# Mostrar Imagen (Opcional en JupyterLab)
plt.show()

# %%
from mpl_toolkits import mplot3d
#%matplotlib widget

plt.close('all')
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection="3d")
ax.scatter3D(df['length'], df['width'], df['height'], alpha=0.4, s=60)
ax.set_xlabel("Longitud")
ax.set_ylabel("Ancho")
ax.set_zlabel("Altura")
ax.set_title("Relación entre altura, ancho y largo ");

# %%
#Las dimensiones pueden representar una caracteristica de los datos, por ejemplo, la relacion entre variables
#El ancho de los puntos


#Agrupacion de nubes de puntos, clusterizacion



#Fenomeno del espacio vacio

# %%
#FENOMENO DEL ESPACIO VACIO


#ENTRE MAS PUNTOS SE UTILICEN PARA COMPLETAR UN PLANO, LOS PUNTOS SE ESPARCEN
#Mas dimensiones, mas espacios vacios

#Entre mas variables de clasificacion, menos performance de desarollo

# %% [markdown]
# Existe la posibilidad de reducir la dimension.
#
# Desenvolver el rollo suizo.
#
# Comprimi?
#
# la banda de mobius, ejemplo de que la compresion, no siempre es facil de hacer
# Banda de Klein

# %% [markdown]
# Metodos de reduccion
#
# PCA: Aplastar los datos?, en la direccion que tiene mayor varianza
#
# KERNEL PCA:
# LINEAL LOCAL EMBEBING
#
# Se debe utilizar el metodo para el tipo de problema

# %% [markdown]
# Tipo,
#
# Reduccion para el proposito de visualizacion:
#
# T-SNE
#
# SOM (MAPAS AUTO-ORGANIZADOS)
#
# LDA
#
#
#
#
# Reduccion para visualizacion y modelizacion

# %% [markdown]
# # T-SNE

# %%
#Representar datos en un hiper plano mantiendo la varianza como sea posible

# %%
#from keras.datasets import mnist

#labels = mnist.values[:,0]
#features = mnist.values[:,1:]

# %% [markdown]
# # SOM

# %%
#Libro de codigos de tal manera que cada dato se puede asociar a un codigo que este cerca de otro dato orginal


#Proberty MAP SOM

#Permite ver como se van transformando los datos
#Por ejemplo, cuando se deforma un 5, se va pareciendo mas a un 6

# %% [markdown]
# ## **Metodos para visualizacion y modelizacion**

# %% [markdown]
# PCA

# %%
#UMAP, RECORDAR, METODOS DE REDUCCION DE DIMENSION PARA MODELIZACION

# %% [markdown]
# ICA Analisis de componentes independientes
#
#
# Los features de entrada se pueden separar en features independientes

# %%
#Nota, este metodo no se utiliza para clustering, se pueden comprimir, descomprimir y reconstruir

#Utilizado para problamente envio de señales

# %% [markdown]
# ISOMAP

# %%
# La distancia entre puntos se mide a lo largo de la variedad, como medir sobre la tierra y no al estilo euclidiano.

# Desdoblamiento

# %% [markdown]
# LLE

# %%
#Intenta descubrir la estructura no lineal en datos de alta dimension mediante la explotacion de simetrias locales.

#Coger como parches?, para represantarlo en un plano dos.

# %% [markdown]
# UMAP

# %% [markdown]
# https://umap-learn.readthedocs.io/en/latest/

# %%
#Sentence transformer, transformar texto a numeros
